# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats

df = pd.read_csv('Data/Running.csv')
df.head()
# Out:
#    Athlete MileMinDur
# 0        0    0:06:21
# 1        0    0:07:00
# 2        0    0:12:44
# 3        1    0:06:25
# 4        1    0:07:24

# %%
df['MileSecDur'] = df['MileMinDur'].apply(lambda x: int(x.split(':')[1])*60 + int(x.split(':')[2]))

# %%
athletes = df[df['Athlete'] == 1]['MileSecDur']
non_athletes = df[df['Athlete'] == 0]['MileSecDur']

# %%
athletes.hist()
# Out:
# <AxesSubplot:>

# %%
non_athletes.hist()
# Out:
# <AxesSubplot:>

# %%
athletes.var()
# Out:
# 2444.858853596203

# %%
non_athletes.var()
# Out:
# 14802.27848574238

# %%
sns.boxplot(x=df['Athlete'], y=df['MileSecDur'])
plt.show()

# %% [markdown]
# * Двусторонний t-test
# * alpha = 0.05
# * Critical value: ±1.9667
# * Critical region: (-∞, -1.9667] ∪ [1.9667, ∞)
#
# Односторонний: Critical Value of t (Right Tailed): 1.65

# %%
n_1 = len(non_athletes)
n_2 = len(athletes)
print(n_1, n_2)
# Out:
# 226 166

# %%
mean_1 = non_athletes.mean()
mean_2 = athletes.mean()
print(mean_1, mean_2)
# Out:
# 546.1017699115044 411.31325301204816

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
var_1 = non_athletes.var()
var_2 = athletes.var()
print(var_1, var_2)
# Out:
# 14802.27848574238 2444.858853596203

# %%
s_m1_m2 = np.sqrt(var_1/n_1 + var_2/n_2)
print(s_m1_m2)
# Out:
# 8.956833862596019

# %%
t = (mean_1 - mean_2) / s_m1_m2
print(t)
# Out:
# 15.048678915697742

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
v_1 = var_1/n_1
v_2 = var_2/n_2

df_welch = (v_1 + v_2)**2 / (v_1**2 / n_1 - 1 + v_2**2 / n_2 - 1)
print(df_welch)
print(int(df_welch))
# Out:
# 351.92104446525263
# 351

# %%
df_student = n_2 + n_1 - 2
print(df_student)
# Out:
# 390

# %% [markdown]
# https://en.wikipedia.org/wiki/Student%27s_t-distribution#Table_of_selected_values

# %%
import scipy.stats

# %%
scipy.stats.ttest_ind_from_stats(mean_1, np.sqrt(var_1), n_1, 
                                 mean_2, np.sqrt(var_2), n_2, equal_var=False)
# Out:
# Ttest_indResult(statistic=15.048678915697742, pvalue=5.824578890260176e-39)

# %%
scipy.stats.ttest_ind(non_athletes, athletes, equal_var=False)
# Out:
# Ttest_indResult(statistic=15.048678915697742, pvalue=5.82457889026026e-39)
